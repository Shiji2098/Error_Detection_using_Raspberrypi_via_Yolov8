# %%
from google.colab import drive
drive.mount('content')
# Out:
# Mounted at content

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/112.6 GB disk)

# %%
# Train YOLOv8n on created dataset for 300 epochs
# !yolo train model='/content/content/MyDrive/Mini_projects/defects/yolov8n.pt' data='/content/content/MyDrive/Mini_projects/defects/dataset_yolo/data.yaml' epochs=300 imgsz=640
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model='/content/content/MyDrive/Mini_projects/defects/best.pt' source='/content/content/MyDrive/Mini_projects/defects/dataset_yolo/train/images/A029-20230621_114525_bmp.rf.98729d08024f60a21e40ba0707659f02.jpg'
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/content/MyDrive/Mini_projects/defects/dataset_yolo/train/images/A029-20230621_114525_bmp.rf.98729d08024f60a21e40ba0707659f02.jpg: 512x640 4 error2s, 47.8ms
# Speed: 3.8ms preprocess, 47.8ms inference, 587.3ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
